# %%
import os

# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir("/content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason/tissues_train")
# !pwd
# Out:
# /content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason/tissues_train

# %%
folder = "/content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason/tissues_train"
import os
pathiter = (os.path.join(root, filename)
    for root, _, filenames in os.walk(folder)
    for filename in filenames
)
for path in pathiter:
    newname =  path.replace('mask_', '')
    if newname != path:
        os.rename(path,newname)

# %%
import cv2, json
import numpy as np
from google.colab.patches import cv2_imshow

#!wget https://www.dropbox.com/s/ocuwkmgigzvsu6e/mask_ZT76_39_B_2_5.png?dl=0 -O mask_ZT76_39_B_2_5.png
#!wget https://www.dropbox.com/s/excbs4zq92kxf02/mask_ZT76_39_A_1_3.png?dl=0 -O mask_ZT76_39_A_1_3.png
#!wget https://www.dropbox.com/s/gf2wi9mz1dhrmos/mask_ZT76_39_A_1_12.png?dl=0 -O mask_ZT76_39_A_1_12.png


def contornos_por_color(imagen,color):
	img = cv2.imread(imagen)
	imghsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

	if color=="amarillo":
		lower = np.array([29,255,255])
		upper = np.array([30,255,255])

	if color=="azul":
		lower = np.array([110,255,255])
		upper = np.array([130,255,255])

	if color=="rojo":
		lower = np.array([0,255,255])
		upper = np.array([10,255,255])
    
	if color=="verde":
		lower = np.array([55,255,255])
		upper = np.array([65,255,255])

	mask = cv2.inRange(imghsv, lower, upper)
	contours, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
	poligono,poligonos=[],[]

	for k in range(len(contours)):
	  for i in range(len(contours[k])):
	    poligono.append([contours[k][i][0][0],contours[k][i][0][1]])
	  poligonos.append(poligono[1::2])
	  poligono = []

	
	for i in range(len(poligonos)):
	  shapes.append(
	    {
	      "label": color,
	      "line_color": None,
	      "fill_color": None,
	      "points": [[int(k[0]),int(k[1])] for k in poligonos[i]],
	      "shape_type": "polygon"
	    }
	  )

	return shapes

# %%
import os

path, dirs, files = next(os.walk("."))
for file in files:
    if file.endswith(".png"):
      shapes=[]
      
      shapes_ = contornos_por_color(file,"amarillo")
      shapes_ = contornos_por_color(file,"azul")
      shapes_ = contornos_por_color(file,"rojo")
      shapes_ = contornos_por_color(file,"verde")


      diccionario = {
        "version": "3.14.2",
        "flags": {},
        "shapes": shapes,
        "lineColor": [
          0,
          255,
          0,
          128
        ],
        "fillColor": [
          255,
          0,
          0,
          128
        ],
        "imagePath": file,
        "imageHeight": 3100,
        "imageWidth": 3100
      }

      with open(file[:-4]+'.json', 'w') as json_salida:
          json.dump(diccionario, json_salida, indent=4)
      print("OK - ",file)
# Out:
# OK -  ZT199_1_A_7_9.png
# OK -  ZT199_1_A_7_4.png
# OK -  ZT199_1_A_8_4.png
# OK -  ZT199_1_A_8_13.png
# OK -  ZT199_1_A_7_8.png
# OK -  ZT199_1_A_8_11.png
# OK -  ZT199_1_A_7_2.png
# OK -  ZT199_1_B_2_1.png
# OK -  ZT199_1_B_2_3.png
# OK -  ZT199_1_B_2_10.png
# OK -  ZT199_1_B_1_7.png
# OK -  ZT199_1_B_1_3.png
# OK -  ZT199_1_B_2_11.png
# OK -  ZT199_1_A_8_8.png
# OK -  ZT199_1_B_1_8.png
# OK -  ZT199_1_B_2_2.png
# OK -  ZT199_1_B_2_8.png
# OK -  ZT199_1_A_8_9.png
# OK -  ZT199_1_B_3_10.png
# OK -  ZT199_1_B_1_10.png
# OK -  ZT199_1_B_1_11.png
# OK -  ZT199_1_B_2_7.png
# OK -  ZT199_1_B_2_13.png
# OK -  ZT199_1_B_4_9.png
# OK -  ZT199_1_B_5_1.png
# OK -  ZT199_1_B_4_10.png
# OK -  ZT199_1_B_4_6.png
# OK -  ZT199_1_B_3_9.png
# OK -  ZT199_1_B_3_2.png
# OK -  ZT199_1_B_3_6.png
# OK -  ZT199_1_B_4_2.png
# OK -  ZT199_1_B_4_12.png
# OK -  ZT199_1_B_3_7.png
# OK -  ZT199_1_B_3_4.png
# OK -  ZT199_1_B_4_4.png
# OK -  ZT199_1_B_6_5.png
# OK -  ZT199_1_B_5_4.png
# OK -  ZT199_1_B_5_5.png
# ...

# %%
os.chdir("/content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason/tissues_test")
# !pwd
# Out:
# /content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason/tissues_test

# %%
folder = "/content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason/tissues_test"
import os
pathiter = (os.path.join(root, filename)
    for root, _, filenames in os.walk(folder)
    for filename in filenames
)
for path in pathiter:
    newname =  path.replace('mask1_', '')
    if newname != path:
        os.rename(path,newname)

# %%
import os

path, dirs, files = next(os.walk("."))
for file in files:
    if file.endswith(".png"):
      shapes=[]
      
      shapes_ = contornos_por_color(file,"amarillo")
      shapes_ = contornos_por_color(file,"azul")
      shapes_ = contornos_por_color(file,"rojo")
      shapes_ = contornos_por_color(file,"verde")


      diccionario = {
        "version": "3.14.2",
        "flags": {},
        "shapes": shapes,
        "lineColor": [
          0,
          255,
          0,
          128
        ],
        "fillColor": [
          255,
          0,
          0,
          128
        ],
        "imagePath": file,
        "imageHeight": 3100,
        "imageWidth": 3100
      }

      with open(file[:-4]+'.json', 'w') as json_salida:
          json.dump(diccionario, json_salida, indent=4)
      print("OK - ",file)
# Out:
# OK -  ZT80_38_A_2_11.png
# OK -  ZT80_38_A_6_14.png
# OK -  ZT80_38_B_7_7.png
# OK -  ZT80_38_C_8_9.png
# OK -  ZT80_38_A_1_13.png
# OK -  ZT80_38_A_1_11.png
# OK -  ZT80_38_A_1_1.png
# OK -  ZT80_38_A_1_10.png
# OK -  ZT80_38_A_1_9.png
# OK -  ZT80_38_A_2_8.png
# OK -  ZT80_38_A_3_7.png
# OK -  ZT80_38_A_2_4.png
# OK -  ZT80_38_A_1_5.png
# OK -  ZT80_38_A_3_13.png
# OK -  ZT80_38_A_3_8.png
# OK -  ZT80_38_A_3_1.png
# OK -  ZT80_38_A_3_11.png
# OK -  ZT80_38_A_2_14.png
# OK -  ZT80_38_A_1_8.png
# OK -  ZT80_38_A_1_2.png
# OK -  ZT80_38_A_2_13.png
# OK -  ZT80_38_A_1_14.png
# OK -  ZT80_38_A_2_1.png
# OK -  ZT80_38_A_3_6.png
# OK -  ZT80_38_A_3_2.png
# OK -  ZT80_38_A_3_14.png
# OK -  ZT80_38_A_1_4.png
# OK -  ZT80_38_A_3_4.png
# OK -  ZT80_38_A_2_12.png
# OK -  ZT80_38_A_1_7.png
# OK -  ZT80_38_A_4_12.png
# OK -  ZT80_38_A_5_13.png
# OK -  ZT80_38_A_4_8.png
# OK -  ZT80_38_A_5_3.png
# OK -  ZT80_38_A_5_11.png
# OK -  ZT80_38_A_4_2.png
# OK -  ZT80_38_A_4_10.png
# ...

# %%
#os.chdir("/content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason_4_5/tissues_train")

# %%
#path, dirs, files = next(os.walk("."))
#for file in files:
#    if file.endswith(".png"):
#      os.remove(file)

# %%
#os.chdir("/content/drive/My Drive/PROYECTO_DE_GRADO/codigo/Gleason_4_5/tissues_test")

# %%
#path, dirs, files = next(os.walk("."))
#for file in files:
#    if file.endswith(".png"):
#      os.remove(file)

# %%
os.chdir("/content")
# !pwd
# Out:
# /content
